# %% [markdown]
# <a href="https://colab.research.google.com/github/C03lh0/SuperPixel_Hierarchy/blob/main/Graphs%5BSpike%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
img = plt.imread('flower.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (720, 960, 3)

# %%
plt.imshow(img)
plt.xticks([],[])
plt.yticks([],[])
# Out:
# ([], [])

# %%
plt.imshow(np.invert(img))
plt.xticks([],[])
plt.yticks([],[])
# Out:
# ([], [])

# %%
plt.imshow(img[:,:,0], cmap='gray')

# %%
plt.imshow(img[:,:,1], cmap='gray')

# %%
plt.imshow(img[:,:,2], cmap='gray')

# %%
img_R = img.copy()
img_R[:,:, [1,2]] = 0
plt.imshow(img_R)
plt.xticks([],[])
plt.yticks([],[])
# Out:
# ([], [])

# %%
img_R = img.copy()
img_R[:,:, [0,2]] = 0
plt.imshow(img_R)
plt.xticks([],[])
plt.yticks([],[])
# Out:
# ([], [])

# %%
img_R = img.copy()
img_R[:,:, [0,1]] = 0
plt.imshow(img_R)
plt.xticks([],[])
plt.yticks([],[])
# Out:
# ([], [])
